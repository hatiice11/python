# %%
# kütüphaneleri ekledik
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/My Drive/pythonProje")
# !pwd
# Out:
# /content/drive/My Drive/pythonProje

# %%
df=pd.read_csv("HAM10000_metadata.csv")
df.head()
df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
#Veri Setinden Bağımlı ve Bağımsız Değişkenleri Oluşturmak
x = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

# %%
df.describe()
# Out:
#                age
# count  9958.000000
# mean     51.863828
# std      16.968614
# min       0.000000
# 25%      40.000000
# 50%      50.000000
# 75%      65.000000
# max      85.000000

# %%
#yaşa göre sivilcenin nerede çıktığına bakıyoruz yüz, kol, bacak...
# plot data
plt.scatter(df.age,df.localization)
plt.xlabel("age")
plt.ylabel("localization")
plt.show()

# %%
# cinsiyete göre sivilcenin nerede çıktığına bakıyoruz yüz, kol, bacak...
# plot data
plt.scatter(df.sex,df.localization)
plt.xlabel("sex")
plt.ylabel("localization")
plt.show()

# %%
x=df['age']
y=df['localization']

# %%
#Değişkenlerimizi Eğitim ve Test Olmak Üzere İkiye Bölmek
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.regression import linear_model

# %%
x_train = sm.add_constant(x_train) #MODEL SABİT TERİM İÇERDİĞİ İÇİN SABİT DEĞİŞKEN EKLENDİ
x_train
# Out:
#       const   age
# 5776    1.0  50.0
# 5656    1.0  45.0
# 2470    1.0  85.0
# 1624    1.0  50.0
# 5173    1.0  35.0
# ...     ...   ...
# 9225    1.0  30.0
# 4859    1.0  65.0
# 3264    1.0  50.0
# 9845    1.0  65.0
# 2732    1.0  65.0
#
# [8012 rows x 2 columns]

# %%
#bu kod ile lineer regresyonu tanımlamış olduk
from sklearn.linear_model import LinearRegression

linear_reg=LinearRegression()

y=df.sex.values.reshape(-1,1)

x=df.localization.values.reshape(-1,1)

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

le=LabelEncoder()
df['localization']=le.fit_transform(df['localization'])
df['localization']
# Out:
# 0        11
# 1        11
# 2        11
# 3        11
# 4         4
#          ..
# 10010     0
# 10011     0
# 10012     0
# 10013     5
# 10014     2
# Name: localization, Length: 10015, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

linear_reg=LinearRegression()

y=df.age.values.reshape(-1,1)

x=df.localization.values.reshape(-1,1)

# %%
df.fillna(999, inplace=True)

# %%
#Modeli Eğitme
linear_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
tahmin=linear_reg.predict([[15]])
print(tahmin)
# Out:
# [[66.30680265]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier(max_depth=2,random_state=0)

# %%
plt.scatter(x_train, y_train, color = 'red')
modelin_tahmin_ettigi_y = linear_reg.predict(x_train)
plt.scatter(x_train, modelin_tahmin_ettigi_y, color = 'blue')
plt.title('Yaş a Göre sivilcenin nerede daha çok çıktığının Tahmini Regresyon Modeli')
plt.xlabel('age')
plt.ylabel('localization')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2653168b9b90> in <cell line: 1>()
# ----> 1 plt.scatter(x_train, y_train, color = 'red')
#       2 modelin_tahmin_ettigi_y = linear_reg.predict(x_train)
#       3 plt.scatter(x_train, modelin_tahmin_ettigi_y, color = 'blue')
#       4 plt.title('Yaş a Göre sivilcenin nerede daha çok çıktığının Tahmini Regresyon Modeli')
#       5 plt.xlabel('age')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...

# %%
plt.scatter(x_train, y_train, color = 'red')
modelin_tahmin_ettigi_y = linear_reg.predict(x_train)
plt.plot(x_train, modelin_tahmin_ettigi_y, color = 'blue')
plt.title('Cinsiyete  Göre sivilcenin nerede daha çok çıktığının Tahmini Regresyon Modeli')
plt.xlabel('sex')
plt.ylabel('localization')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-aa30c206eef0> in <cell line: 1>()
# ----> 1 plt.scatter(x_train, y_train, color = 'red')
#       2 modelin_tahmin_ettigi_y = linear_reg.predict(x_train)
#       3 plt.plot(x_train, modelin_tahmin_ettigi_y, color = 'blue')
#       4 plt.title('Cinsiyete  Göre sivilcenin nerede daha çok çıktığının Tahmini Regresyon Modeli')
#       5 plt.xlabel('sex')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...

# %%
le=LabelEncoder()
df['age']=le.fit_transform(df['age'])

le=LabelEncoder()
df['localization']=le.fit_transform(df['localization'])

# %%
from sklearn.model_selection import train_test_split

x_train , x_test, y_train , y_test=train_test_split(x,y, test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.12081877184223665

# %%
from sklearn.model_selection import train_test_split

x_train , x_test, y_train , y_test=train_test_split(x,y, test_size=0.2,random_state=42)
